# %% [markdown]
# # Generate training results

# %%
from myst_nb import glue

# %% [markdown]
# ## Results on dev set
# The evaluation of automatic predictions had two different scenarios or sub-tracks:
#
# 1.  **NER offset and entity type classification**: the first sub-track was focused
# on the identification and classification of sensitive information (e.g., patient
# names, telephones, addresses, etc.).
#
# 2.  **Sensitive span detection**: the second sub-track was focused on the detection
# of sensitive text more specific to the practical scenario necessary for the
# release of de-identified clinical documents, where the objective is to identify
# and to mask confidential data, regardless of the real type of entity or the
# correct identification of PHI type.
#
# We evaluate our models using the various evaluation scripts and report averaged F1-Score over treee runs.

# %% [markdown]
# First create some code to automatically extract the evaluation results.

# %%
import pandas as pd
from collections import defaultdict
from pathlib import Path
from typing import Callable, DefaultDict, List, NamedTuple


class SubtrackScores(NamedTuple):
    precision: float
    recall: float

def _get_scores(folder_path: Path, filename: str, precision_line: int, recall_line: int) -> SubtrackScores:
    fpth = Path(folder_path / filename)
    if not fpth.exists():
        raise FileNotFoundError(f"{fpth} not found!")

    lines = fpth.read_text().split("\n")

    precision = float(lines[precision_line].split("=")[-1])
    recall = float(lines[recall_line].split("=")[-1])

    return SubtrackScores(precision, recall)

def get_subtrack1_scores(folder_path: Path) -> SubtrackScores:
    return _get_scores(folder_path, "ner", -3, -2)

def get_subtrack2_strict_scores(folder_path: Path) -> SubtrackScores:
    return _get_scores(folder_path, "spans", -6, -5)

def get_subtrack2_merged_scores(folder_path: Path) -> SubtrackScores:
    return _get_scores(folder_path, "spans", -3, -2)

def get_scores_as_df(seeds: List[int], get_folder: Callable[[int], Path]) -> pd.DataFrame:
    subtracks_scores: DefaultDict[List, float] = defaultdict(list)

    for seed in seeds:
        fpth = get_folder(seed)

        p, r = get_subtrack1_scores(fpth)
        subtracks_scores["1_p"].append(p)
        subtracks_scores["1_r"].append(r)

        p, r = get_subtrack2_strict_scores(fpth)
        subtracks_scores["2_1_p"].append(p)
        subtracks_scores["2_1_r"].append(r)

        p, r = get_subtrack2_merged_scores(fpth)
        subtracks_scores["2_2_p"].append(p)
        subtracks_scores["2_2_r"].append(r)

    df = pd.DataFrame.from_dict(subtracks_scores)
    for col in ["1", "2_1", "2_2"]:
        df[f"{col}_f1"] = 2*df[f"{col}_p"]*df[f"{col}_r"] / (df[f"{col}_p"] + df[f"{col}_r"])

    # Reorder columns
    new_columns = ["1_p", "1_r", "1_f1", "2_1_p", "2_1_r", "2_1_f1", "2_2_p", "2_2_r", "2_2_f1"]
    df = df[new_columns]

    # Prepare multi index names
    multi_index = pd.MultiIndex.from_product(
        [
            ["Subtrack 1", "Subtrack 2 [Strict]", "Subtrack 2 [Merged]"],
            ["precision", "recall", "f1"]
        ],
        names=["Track", "Scores"]
    )
    # Give multi index to df
    return pd.DataFrame(df.to_numpy().T, index=multi_index)

# %% [markdown]
# 2. Define code to visualize the results in a convenient way

# %%
import pandas as pd
import matplotlib.pyplot as plt  
from matplotlib import colors

def make_pretty(styler):
    styler.set_table_styles([
        {'selector': '.index_name', 'props': 'font-style: italic; color: darkgrey; font-weight:normal;'},
        {'selector': 'th.level1', 'props': 'text-align: left;'},
        {'selector': 'th.level0', 'props': 'text-align: center;'},
        {'selector': 'th.col_heading', 'props': 'text-align: center;'},
        {'selector': 'th.col_heading.level0', 'props': 'font-size: 1.5em;'},
        {'selector': 'td', 'props': 'text-align: center; font-weight: bold;'},
    ], overwrite=False)
    # .set_caption("Ajuste fino evaluado con distinctas métricas")
    styler.hide(axis="index", level=2)
    styler.hide(axis="columns", level=1)
    styler.format(precision=2)
    return styler

def visualize_df(df: pd.DataFrame):
    # Get the text that will be display in the form mean plus minus std
    std = (df*100).iloc[1::2, ::].round(2).astype(str).droplevel(2)
    mean = (df*100).iloc[::2, ::].round(2).astype(str).droplevel(2)
    df_txt = (mean + " \u00b1 " + std)

    # Extract the mean value that will serve to create the gradient map
    background_df = df.iloc[::2, ::]

    def b_g(s, cmap='PuBu', low=0, high=0):
        # Taken from https://stackoverflow.com/questions/47391948/pandas-style-background-gradient-using-other-dataframe
        nonlocal background_df
        # Pass the columns from Dataframe background_df
        a = background_df.loc[:,s.name].copy()
        rng = a.max() - a.min()
        norm = colors.Normalize(a.min() - (rng * low), a.max() + (rng * high))
        normed = norm(a.values)
        c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed*0.9)]
        return ['background-color: %s' % color for color in c]

    return df_txt.style.apply(b_g, cmap='PuBu').pipe(make_pretty)

# %% [markdown]
# Define the root folder where all the results and the trained models are stored

# %%
base_folder = Path.cwd().parents[1]

# %% [markdown]
# Store the evaluation for each model in a ``pandas.DataFrame``.

# %%
from functools import partial

metric = "f1"
dataset = "dev"

def get_results(metric: str = "f1", dataset: str = "dev") -> pd.DataFrame:
    get_scores_as_df_with_seed = partial(get_scores_as_df,  [1, 12, 33])
    get_folders_all = {
        # ("LSTM CRF", "FLAIR + WE"): lambda seed: base_folder / f"experiments/corpus_sentence_flair_we_lstm_crf/results_seed_{seed}/evals/{dataset}",
        ("LSTM CRF", "FLAIR"): lambda seed: base_folder / f"experiments/corpus_sentence_flair_lstm_crf/an_wh_rs_True_dpt_0.08716810045694838_emb_seed_{seed}_Stack(0_lm-es-forward.pt, 1_lm-es-backward.pt)_hdn_sz_256_lr_0.1_it_150_bs_4_opti_SGD_pjct_emb_True_rnn_ly_2_sdl_AnnealOnPlateau_use_crf_True_use_rnn_True/0/evals/{dataset}",
        ("LSTM CRF", "BETO + CONTEXT"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_context_lstm_crf/an_wh_rs_False_dpt_0_emb_beto_Ly_all_mean_context_seed_{seed}_hdn_sz_256_lr_0.1_it_500_bs_4_opti_SGD_pjct_emb_False_rnn_ly_2_sdl_AnnealOnPlateau_use_crf_True_use_rnn_True/0/evals/{dataset}",
        ("LSTM CRF", "BETO"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_lstm_crf/an_wh_rs_False_dpt_0_emb_beto_Ly_all_mean_seed_{seed}_hdn_sz_256_lr_0.1_it_500_bs_4_opti_SGD_pjct_emb_False_rnn_ly_2_sdl_AnnealOnPlateau_use_crf_True_use_rnn_True/0/evals/{dataset}",
        ("LSTM CRF", "BETO + WE + CONTEXT"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_context_we_lstm_crf/an_wh_rs_False_dpt_0_emb_Stack(0_es-wiki-fasttext-300d-1M, 1_1-beto_Ly_all_mean_context_seed_{seed})_hdn_sz_256_lr_0.1_it_500_bs_4_opti_SGD_pjct_emb_False_rnn_ly_2_sdl_AnnealOnPlateau_use_crf_True_use_rnn_True/0/evals/{dataset}",
        ("LSTM CRF", "BETO + WE"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_we_lstm_crf/an_wh_rs_False_dpt_0_emb_Stack(0_es-wiki-fasttext-300d-1M, 1_1-beto_Ly_all_mean_seed_{seed})_hdn_sz_256_lr_0.1_it_500_bs_4_opti_SGD_pjct_emb_False_rnn_ly_2_sdl_AnnealOnPlateau_use_crf_True_use_rnn_True/0/evals/{dataset}",
        ("FINETUNE", "BETO + CONTEXT"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_context_finetune/an_wh_rs_False_dpt_0_emb_beto-cased-context_FT_True_Ly_-1_seed_{seed}_lr_5e-06_it_150_bs_4_opti_AdamW_pjct_emb_False_sdl_LinearSchedulerWithWarmup_use_crf_False_use_rnn_False_wup_0.1/0/evals/{dataset}",
        ("FINETUNE", "BETO + WE + CONTEXT"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_context_we_finetune_it_150/an_wh_rs_False_dpt_0_emb_Stack(0_es-wiki-fasttext-300d-1M, 1_1-beto-cased_FT_True_Ly_-1_seed_{seed})_lr_5e-06_it_150_bs_4_opti_AdamW_pjct_emb_False_sdl_LinearSchedulerWithWarmup_use_crf_False_use_rnn_False_wup_0.1/0/evals/{dataset}",
        ("FINETUNE", "BETO"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_finetune_it_150/an_wh_rs_False_dpt_0_emb_beto-cased_FT_True_Ly_-1_seed_{seed}_lr_5e-06_it_150_bs_4_opti_AdamW_pjct_emb_False_sdl_LinearSchedulerWithWarmup_use_crf_False_use_rnn_False_wup_0.1/0/evals/{dataset}",
        ("FINETUNE", "BETO + WE"): lambda seed: base_folder / f"experiments/corpus_sentence_bert_we_finetune_it_150/an_wh_rs_False_dpt_0_emb_Stack(0_es-wiki-fasttext-300d-1M, 1_1-beto-cased_FT_True_Ly_-1_seed_{seed})_lr_5e-06_it_150_bs_4_opti_AdamW_pjct_emb_False_sdl_LinearSchedulerWithWarmup_use_crf_False_use_rnn_False_wup_0.1/0/evals/{dataset}",
        ("FINETUNE", "XLMRL + CONTEXT"): lambda seed: base_folder / f"experiments/corpus_sentence_xlmrl_context_finetune/an_wh_rs_False_dpt_0_emb_xlm-roberta-large-cased-context_FT_True_Ly_-1_seed_{seed}_lr_5e-06_it_40_bs_4_opti_AdamW_pjct_emb_False_sdl_LinearSchedulerWithWarmup_use_crf_False_use_rnn_False_wup_0.1/0/evals/{dataset}",
        ("FINETUNE", "XLMRL"): lambda seed: base_folder / f"experiments/corpus_sentence_xlmrl_finetune/an_wh_rs_False_dpt_0_emb_xlm-roberta-large-cased_FT_True_Ly_-1_seed_{seed}_lr_5e-06_it_40_bs_4_opti_AdamW_pjct_emb_False_sdl_LinearSchedulerWithWarmup_use_crf_False_use_rnn_False_wup_0.05/0/evals/{dataset}",
        ("FINETUNE", "XLMRL + WE"): lambda seed: base_folder / f"experiments/corpus_sentence_xlmrl_we_finetune/an_wh_rs_False_dpt_0_emb_Stack(0_es-wiki-fasttext-300d-1M, 1_1-xlm-roberta-large-cased_FT_True_Ly_-1_seed_{seed})_lr_5e-06_it_40_bs_4_opti_AdamW_pjct_emb_False_sdl_LinearSchedulerWithWarmup_use_crf_False_use_rnn_False_wup_0.05/0/evals/{dataset}",
    }
    dfs_all = {k: get_scores_as_df_with_seed(v).T.describe().T[["mean", "std"]].loc[pd.IndexSlice[:, [f"{metric}"]], :] for k,v in get_folders_all.items()}


    get_scores_as_df_with_seed = partial(get_scores_as_df,  [1, 10, 25, 33, 42])
    get_folders_flair = {
        ("LSTM CRF", "FLAIR + WE"): lambda seed: base_folder / f"experiments/corpus_sentence_flair_we_lstm_crf/results_seed_{seed}/evals/{dataset}",
    }
    dfs_flair = {k: get_scores_as_df_with_seed(v).T.describe().T[["mean", "std"]].loc[pd.IndexSlice[:, [f"{metric}"]], :] for k,v in get_folders_flair.items()}

    dfs = {**dfs_all, **dfs_flair}
    return dfs

dfs = get_results()
result_metrics = pd.concat(dfs.values(), axis=1, keys=sorted(dfs.keys()), names=["Embedding", "Estrategia"]).T
visualize_df(result_metrics)
# Out:
# <style type="text/css">
# #T_daa36 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_daa36 th.level1 {
#   text-align: left;
# }
# #T_daa36 th.level0 {
#   text-align: center;
# }
# #T_daa36 th.col_heading {
#   text-align: center;
# }
# #T_daa36 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_daa36 td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_daa36_row0_col0, #T_daa36_row8_col2 {
#   background-color: #308cbe;
# }
# #T_daa36_row0_col1, #T_daa36_row11_col1 {
#   background-color: #0568a3;
# }
# #T_daa36_row0_col2 {
#   background-color: #4295c3;
# }
# #T_daa36_row1_col0 {
#   background-color: #b9c6e0;
# }
# #T_daa36_row1_col1 {
#   background-color: #94b6d7;
# }
# #T_daa36_row1_col2 {
#   background-color: #d9d8ea;
# }
# #T_daa36_row2_col0 {
#   background-color: #549cc7;
# }
# #T_daa36_row2_col1 {
#   background-color: #056fae;
# }
# #T_daa36_row2_col2 {
#   background-color: #81aed2;
# }
# #T_daa36_row3_col0 {
#   background-color: #0569a4;
# }
# #T_daa36_row3_col1, #T_daa36_row6_col2, #T_daa36_row10_col0 {
#   background-color: #045382;
# }
# #T_daa36_row3_col2 {
#   background-color: #0771b1;
# }
# #T_daa36_row4_col0 {
#   background-color: #2484ba;
# }
# #T_daa36_row4_col1, #T_daa36_row9_col1 {
#   background-color: #0566a0;
# }
# #T_daa36_row4_col2 {
#   background-color: #2182b9;
# }
# #T_daa36_row5_col0 {
#   background-color: #328dbf;
# }
# #T_daa36_row5_col1 {
#   background-color: #1e80b8;
# }
# #T_daa36_row5_col2 {
#   background-color: #4c99c5;
# }
# #T_daa36_row6_col0 {
#   background-color: #0f76b3;
# }
# #T_daa36_row6_col1 {
#   background-color: #04629a;
# }
# #T_daa36_row7_col0 {
#   background-color: #a2bcda;
# }
# #T_daa36_row7_col1 {
#   background-color: #7eadd1;
# }
# #T_daa36_row7_col2 {
#   background-color: #c4cbe3;
# }
# #T_daa36_row8_col0 {
#   background-color: #3991c1;
# }
# #T_daa36_row8_col1 {
#   background-color: #2d8abd;
# }
# #T_daa36_row9_col0, #T_daa36_row11_col0, #T_daa36_row11_col2 {
#   background-color: #046096;
# }
# #T_daa36_row9_col2 {
#   background-color: #4094c3;
# }
# #T_daa36_row10_col1 {
#   background-color: #04588a;
# }
# #T_daa36_row10_col2 {
#   background-color: #0567a1;
# }
# #T_daa36_row12_col0, #T_daa36_row12_col1, #T_daa36_row12_col2 {
#   background-color: #fff7fb;
# }
# </style>
# <table id="T_daa36">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Track</th>
#       <th id="T_daa36_level0_col0" class="col_heading level0 col0" >Subtrack 1</th>
#       <th id="T_daa36_level0_col1" class="col_heading level0 col1" >Subtrack 2 [Strict]</th>
#       <th id="T_daa36_level0_col2" class="col_heading level0 col2" >Subtrack 2 [Merged]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embedding</th>
#       <th class="index_name level1" >Estrategia</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_daa36_level0_row0" class="row_heading level0 row0" rowspan="7">FINETUNE</th>
#       <th id="T_daa36_level1_row0" class="row_heading level1 row0" >BETO</th>
#       <td id="T_daa36_row0_col0" class="data row0 col0" >97.32 ± 0.08</td>
#       <td id="T_daa36_row0_col1" class="data row0 col1" >97.93 ± 0.06</td>
#       <td id="T_daa36_row0_col2" class="data row0 col2" >98.53 ± 0.05</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row1" class="row_heading level1 row1" >BETO + CONTEXT</th>
#       <td id="T_daa36_row1_col0" class="data row1 col0" >97.04 ± 0.08</td>
#       <td id="T_daa36_row1_col1" class="data row1 col1" >97.6 ± 0.1</td>
#       <td id="T_daa36_row1_col2" class="data row1 col2" >98.36 ± 0.13</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row2" class="row_heading level1 row2" >BETO + WE</th>
#       <td id="T_daa36_row2_col0" class="data row2 col0" >97.25 ± 0.07</td>
#       <td id="T_daa36_row2_col1" class="data row2 col1" >97.9 ± 0.02</td>
#       <td id="T_daa36_row2_col2" class="data row2 col2" >98.47 ± 0.06</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row3" class="row_heading level1 row3" >BETO + WE + CONTEXT</th>
#       <td id="T_daa36_row3_col0" class="data row3 col0" >97.46 ± 0.1</td>
#       <td id="T_daa36_row3_col1" class="data row3 col1" >98.02 ± 0.11</td>
#       <td id="T_daa36_row3_col2" class="data row3 col2" >98.59 ± 0.04</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row4" class="row_heading level1 row4" >XLMRL</th>
#       <td id="T_daa36_row4_col0" class="data row4 col0" >97.35 ± 0.18</td>
#       <td id="T_daa36_row4_col1" class="data row4 col1" >97.94 ± 0.17</td>
#       <td id="T_daa36_row4_col2" class="data row4 col2" >98.56 ± 0.14</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row5" class="row_heading level1 row5" >XLMRL + CONTEXT</th>
#       <td id="T_daa36_row5_col0" class="data row5 col0" >97.32 ± 0.1</td>
#       <td id="T_daa36_row5_col1" class="data row5 col1" >97.84 ± 0.1</td>
#       <td id="T_daa36_row5_col2" class="data row5 col2" >98.52 ± 0.03</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row6" class="row_heading level1 row6" >XLMRL + WE</th>
#       <td id="T_daa36_row6_col0" class="data row6 col0" >97.4 ± 0.16</td>
#       <td id="T_daa36_row6_col1" class="data row6 col1" >97.96 ± 0.18</td>
#       <td id="T_daa36_row6_col2" class="data row6 col2" >98.66 ± 0.06</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level0_row7" class="row_heading level0 row7" rowspan="6">LSTM CRF</th>
#       <th id="T_daa36_level1_row7" class="row_heading level1 row7" >BETO</th>
#       <td id="T_daa36_row7_col0" class="data row7 col0" >97.1 ± 0.16</td>
#       <td id="T_daa36_row7_col1" class="data row7 col1" >97.65 ± 0.18</td>
#       <td id="T_daa36_row7_col2" class="data row7 col2" >98.4 ± 0.06</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row8" class="row_heading level1 row8" >BETO + CONTEXT</th>
#       <td id="T_daa36_row8_col0" class="data row8 col0" >97.3 ± 0.08</td>
#       <td id="T_daa36_row8_col1" class="data row8 col1" >97.8 ± 0.1</td>
#       <td id="T_daa36_row8_col2" class="data row8 col2" >98.55 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row9" class="row_heading level1 row9" >BETO + WE</th>
#       <td id="T_daa36_row9_col0" class="data row9 col0" >97.51 ± 0.09</td>
#       <td id="T_daa36_row9_col1" class="data row9 col1" >97.94 ± 0.09</td>
#       <td id="T_daa36_row9_col2" class="data row9 col2" >98.53 ± 0.03</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row10" class="row_heading level1 row10" >BETO + WE + CONTEXT</th>
#       <td id="T_daa36_row10_col0" class="data row10 col0" >97.56 ± 0.16</td>
#       <td id="T_daa36_row10_col1" class="data row10 col1" >98.0 ± 0.17</td>
#       <td id="T_daa36_row10_col2" class="data row10 col2" >98.62 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row11" class="row_heading level1 row11" >FLAIR</th>
#       <td id="T_daa36_row11_col0" class="data row11 col0" >97.51 ± 0.12</td>
#       <td id="T_daa36_row11_col1" class="data row11 col1" >97.93 ± 0.13</td>
#       <td id="T_daa36_row11_col2" class="data row11 col2" >98.63 ± 0.09</td>
#     </tr>
#     <tr>
#       <th id="T_daa36_level1_row12" class="row_heading level1 row12" >FLAIR + WE</th>
#       <td id="T_daa36_row12_col0" class="data row12 col0" >96.75 ± 0.07</td>
#       <td id="T_daa36_row12_col1" class="data row12 col1" >97.24 ± 0.1</td>
#       <td id="T_daa36_row12_col2" class="data row12 col2" >98.27 ± 0.06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Visualize the results for the finetuning strategy with different flavours and the 2 chosen transformers.

# %%
data = {
        ("XLMR LARGE", "transformador lineal"): dfs[("FINETUNE", "XLMRL")],
        ("XLMR LARGE", "+ context"): dfs[("FINETUNE", "XLMRL + CONTEXT")],
        ("XLMR LARGE", "+ we"): dfs[("FINETUNE", "XLMRL + WE")],
        ("BETO", "transformador lineal"): dfs[("FINETUNE", "BETO")],
        ("BETO", "+ Context"): dfs[("FINETUNE", "BETO + CONTEXT")],
        ("BETO", "+ WE"): dfs[("FINETUNE", "BETO + WE")],
        ("BETO", "+ WE + Context"): dfs[("FINETUNE", "BETO + WE + CONTEXT")],
    }
df = pd.concat(data.values(), axis=1, keys=data.keys(), names=["Estrategia", "computation"]).T
glue("table_finetune_dev", visualize_df(df))
# Out:
# <style type="text/css">
# #T_b7ab8 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_b7ab8 th.level1 {
#   text-align: left;
# }
# #T_b7ab8 th.level0 {
#   text-align: center;
# }
# #T_b7ab8 th.col_heading {
#   text-align: center;
# }
# #T_b7ab8 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_b7ab8 td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_b7ab8_row0_col0, #T_b7ab8_row0_col1, #T_b7ab8_row6_col2 {
#   background-color: #045382;
# }
# #T_b7ab8_row0_col2 {
#   background-color: #056fae;
# }
# #T_b7ab8_row1_col0, #T_b7ab8_row2_col0 {
#   background-color: #0567a2;
# }
# #T_b7ab8_row1_col1 {
#   background-color: #0872b1;
# }
# #T_b7ab8_row1_col2 {
#   background-color: #83afd3;
# }
# #T_b7ab8_row2_col1 {
#   background-color: #157ab5;
# }
# #T_b7ab8_row2_col2 {
#   background-color: #04649e;
# }
# #T_b7ab8_row3_col0, #T_b7ab8_row3_col1, #T_b7ab8_row3_col2 {
#   background-color: #fff7fb;
# }
# #T_b7ab8_row4_col0 {
#   background-color: #8eb3d5;
# }
# #T_b7ab8_row4_col1 {
#   background-color: #80aed2;
# }
# #T_b7ab8_row4_col2 {
#   background-color: #8fb4d6;
# }
# #T_b7ab8_row5_col0 {
#   background-color: #9ab8d8;
# }
# #T_b7ab8_row5_col1 {
#   background-color: #a2bcda;
# }
# #T_b7ab8_row5_col2 {
#   background-color: #6ba5cd;
# }
# #T_b7ab8_row6_col0 {
#   background-color: #4496c3;
# }
# #T_b7ab8_row6_col1 {
#   background-color: #056ba7;
# }
# </style>
# <table id="T_b7ab8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Track</th>
#       <th id="T_b7ab8_level0_col0" class="col_heading level0 col0" >Subtrack 1</th>
#       <th id="T_b7ab8_level0_col1" class="col_heading level0 col1" >Subtrack 2 [Strict]</th>
#       <th id="T_b7ab8_level0_col2" class="col_heading level0 col2" >Subtrack 2 [Merged]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Estrategia</th>
#       <th class="index_name level1" >computation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7ab8_level0_row0" class="row_heading level0 row0" rowspan="3">XLMR LARGE</th>
#       <th id="T_b7ab8_level1_row0" class="row_heading level1 row0" >transformador lineal</th>
#       <td id="T_b7ab8_row0_col0" class="data row0 col0" >97.56 ± 0.16</td>
#       <td id="T_b7ab8_row0_col1" class="data row0 col1" >98.0 ± 0.17</td>
#       <td id="T_b7ab8_row0_col2" class="data row0 col2" >98.62 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_b7ab8_level1_row1" class="row_heading level1 row1" >+ context</th>
#       <td id="T_b7ab8_row1_col0" class="data row1 col0" >97.51 ± 0.09</td>
#       <td id="T_b7ab8_row1_col1" class="data row1 col1" >97.94 ± 0.09</td>
#       <td id="T_b7ab8_row1_col2" class="data row1 col2" >98.53 ± 0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b7ab8_level1_row2" class="row_heading level1 row2" >+ we</th>
#       <td id="T_b7ab8_row2_col0" class="data row2 col0" >97.51 ± 0.12</td>
#       <td id="T_b7ab8_row2_col1" class="data row2 col1" >97.93 ± 0.13</td>
#       <td id="T_b7ab8_row2_col2" class="data row2 col2" >98.63 ± 0.09</td>
#     </tr>
#     <tr>
#       <th id="T_b7ab8_level0_row3" class="row_heading level0 row3" rowspan="4">BETO</th>
#       <th id="T_b7ab8_level1_row3" class="row_heading level1 row3" >transformador lineal</th>
#       <td id="T_b7ab8_row3_col0" class="data row3 col0" >97.1 ± 0.16</td>
#       <td id="T_b7ab8_row3_col1" class="data row3 col1" >97.65 ± 0.18</td>
#       <td id="T_b7ab8_row3_col2" class="data row3 col2" >98.4 ± 0.06</td>
#     </tr>
#     <tr>
#       <th id="T_b7ab8_level1_row4" class="row_heading level1 row4" >+ Context</th>
#       <td id="T_b7ab8_row4_col0" class="data row4 col0" >97.32 ± 0.1</td>
#       <td id="T_b7ab8_row4_col1" class="data row4 col1" >97.84 ± 0.1</td>
#       <td id="T_b7ab8_row4_col2" class="data row4 col2" >98.52 ± 0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b7ab8_level1_row5" class="row_heading level1 row5" >+ WE</th>
#       <td id="T_b7ab8_row5_col0" class="data row5 col0" >97.3 ± 0.08</td>
#       <td id="T_b7ab8_row5_col1" class="data row5 col1" >97.8 ± 0.1</td>
#       <td id="T_b7ab8_row5_col2" class="data row5 col2" >98.55 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_b7ab8_level1_row6" class="row_heading level1 row6" >+ WE + Context</th>
#       <td id="T_b7ab8_row6_col0" class="data row6 col0" >97.4 ± 0.16</td>
#       <td id="T_b7ab8_row6_col1" class="data row6 col1" >97.96 ± 0.18</td>
#       <td id="T_b7ab8_row6_col2" class="data row6 col2" >98.66 ± 0.06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Visualize the results for the lstm+crf strategy with different flavours and the 2 chosen transformers.

# %%
data = {
        ("LSTM CRF", "BETO (Ultimas 4 capas)"): dfs[("LSTM CRF", "BETO")],
        ("LSTM CRF", "+ Context"): dfs[("LSTM CRF", "BETO + CONTEXT")],
        ("LSTM CRF", "+ WE"): dfs[("LSTM CRF", "BETO + WE")],
        ("LSTM CRF", "+ WE + Context"): dfs[("LSTM CRF", "BETO + WE + CONTEXT")],
    }
df = pd.concat(data.values(), axis=1, keys=data.keys(), names=["Estrategia", "computation"]).T
glue("table_feature_based_dev", visualize_df(df))
# Out:
# <style type="text/css">
# #T_238ac .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_238ac th.level1 {
#   text-align: left;
# }
# #T_238ac th.level0 {
#   text-align: center;
# }
# #T_238ac th.col_heading {
#   text-align: center;
# }
# #T_238ac th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_238ac td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_238ac_row0_col0 {
#   background-color: #83afd3;
# }
# #T_238ac_row0_col1 {
#   background-color: #348ebf;
# }
# #T_238ac_row0_col2 {
#   background-color: #8eb3d5;
# }
# #T_238ac_row1_col0, #T_238ac_row1_col1, #T_238ac_row1_col2 {
#   background-color: #fff7fb;
# }
# #T_238ac_row2_col0 {
#   background-color: #2484ba;
# }
# #T_238ac_row2_col1 {
#   background-color: #0d75b3;
# }
# #T_238ac_row2_col2 {
#   background-color: #0569a4;
# }
# #T_238ac_row3_col0, #T_238ac_row3_col1, #T_238ac_row3_col2 {
#   background-color: #045382;
# }
# </style>
# <table id="T_238ac">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Track</th>
#       <th id="T_238ac_level0_col0" class="col_heading level0 col0" >Subtrack 1</th>
#       <th id="T_238ac_level0_col1" class="col_heading level0 col1" >Subtrack 2 [Strict]</th>
#       <th id="T_238ac_level0_col2" class="col_heading level0 col2" >Subtrack 2 [Merged]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Estrategia</th>
#       <th class="index_name level1" >computation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_238ac_level0_row0" class="row_heading level0 row0" rowspan="4">LSTM CRF</th>
#       <th id="T_238ac_level1_row0" class="row_heading level1 row0" >BETO (Ultimas 4 capas)</th>
#       <td id="T_238ac_row0_col0" class="data row0 col0" >97.25 ± 0.07</td>
#       <td id="T_238ac_row0_col1" class="data row0 col1" >97.9 ± 0.02</td>
#       <td id="T_238ac_row0_col2" class="data row0 col2" >98.47 ± 0.06</td>
#     </tr>
#     <tr>
#       <th id="T_238ac_level1_row1" class="row_heading level1 row1" >+ Context</th>
#       <td id="T_238ac_row1_col0" class="data row1 col0" >97.04 ± 0.08</td>
#       <td id="T_238ac_row1_col1" class="data row1 col1" >97.6 ± 0.1</td>
#       <td id="T_238ac_row1_col2" class="data row1 col2" >98.36 ± 0.13</td>
#     </tr>
#     <tr>
#       <th id="T_238ac_level1_row2" class="row_heading level1 row2" >+ WE</th>
#       <td id="T_238ac_row2_col0" class="data row2 col0" >97.35 ± 0.18</td>
#       <td id="T_238ac_row2_col1" class="data row2 col1" >97.94 ± 0.17</td>
#       <td id="T_238ac_row2_col2" class="data row2 col2" >98.56 ± 0.14</td>
#     </tr>
#     <tr>
#       <th id="T_238ac_level1_row3" class="row_heading level1 row3" >+ WE + Context</th>
#       <td id="T_238ac_row3_col0" class="data row3 col0" >97.46 ± 0.1</td>
#       <td id="T_238ac_row3_col1" class="data row3 col1" >98.02 ± 0.11</td>
#       <td id="T_238ac_row3_col2" class="data row3 col2" >98.59 ± 0.04</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Visualize the results for the lstm+crf strategy with different flavours with Flair embeddings.

# %%
data = {
        ("LSTM CRF", "FLAIR"): dfs[("LSTM CRF", "FLAIR")],
        ("LSTM CRF", "+ WE"): dfs[("LSTM CRF", "FLAIR + WE")],
    }
df = pd.concat(data.values(), axis=1, keys=data.keys(), names=["Estrategia", "computation"]).T
glue("table_flair_dev", visualize_df(df))
# Out:
# <style type="text/css">
# #T_4976e .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_4976e th.level1 {
#   text-align: left;
# }
# #T_4976e th.level0 {
#   text-align: center;
# }
# #T_4976e th.col_heading {
#   text-align: center;
# }
# #T_4976e th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_4976e td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_4976e_row0_col0, #T_4976e_row0_col1, #T_4976e_row0_col2 {
#   background-color: #045382;
# }
# #T_4976e_row1_col0, #T_4976e_row1_col1, #T_4976e_row1_col2 {
#   background-color: #fff7fb;
# }
# </style>
# <table id="T_4976e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Track</th>
#       <th id="T_4976e_level0_col0" class="col_heading level0 col0" >Subtrack 1</th>
#       <th id="T_4976e_level0_col1" class="col_heading level0 col1" >Subtrack 2 [Strict]</th>
#       <th id="T_4976e_level0_col2" class="col_heading level0 col2" >Subtrack 2 [Merged]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Estrategia</th>
#       <th class="index_name level1" >computation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4976e_level0_row0" class="row_heading level0 row0" rowspan="2">LSTM CRF</th>
#       <th id="T_4976e_level1_row0" class="row_heading level1 row0" >FLAIR</th>
#       <td id="T_4976e_row0_col0" class="data row0 col0" >97.32 ± 0.08</td>
#       <td id="T_4976e_row0_col1" class="data row0 col1" >97.93 ± 0.06</td>
#       <td id="T_4976e_row0_col2" class="data row0 col2" >98.53 ± 0.05</td>
#     </tr>
#     <tr>
#       <th id="T_4976e_level1_row1" class="row_heading level1 row1" >+ WE</th>
#       <td id="T_4976e_row1_col0" class="data row1 col0" >96.75 ± 0.07</td>
#       <td id="T_4976e_row1_col1" class="data row1 col1" >97.24 ± 0.1</td>
#       <td id="T_4976e_row1_col2" class="data row1 col2" >98.27 ± 0.06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Results on the test set

# %%
data = get_results(dataset="test")
result_metrics = pd.concat(data.values(), axis=1, keys=sorted(data.keys()), names=["Estrategia", "Embeddings"]).T

glue("table_test", visualize_df(result_metrics))
# Out:
# <style type="text/css">
# #T_9141a .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_9141a th.level1 {
#   text-align: left;
# }
# #T_9141a th.level0 {
#   text-align: center;
# }
# #T_9141a th.col_heading {
#   text-align: center;
# }
# #T_9141a th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_9141a td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_9141a_row0_col0, #T_9141a_row7_col0 {
#   background-color: #f8f1f8;
# }
# #T_9141a_row0_col1 {
#   background-color: #abbfdc;
# }
# #T_9141a_row0_col2 {
#   background-color: #fef6fb;
# }
# #T_9141a_row1_col0 {
#   background-color: #bfc9e1;
# }
# #T_9141a_row1_col1 {
#   background-color: #6fa7ce;
# }
# #T_9141a_row1_col2 {
#   background-color: #e1dfed;
# }
# #T_9141a_row2_col0 {
#   background-color: #8fb4d6;
# }
# #T_9141a_row2_col1 {
#   background-color: #589ec8;
# }
# #T_9141a_row2_col2 {
#   background-color: #b5c4df;
# }
# #T_9141a_row3_col0 {
#   background-color: #0569a4;
# }
# #T_9141a_row3_col1 {
#   background-color: #045f95;
# }
# #T_9141a_row3_col2 {
#   background-color: #056ead;
# }
# #T_9141a_row4_col0, #T_9141a_row6_col1 {
#   background-color: #308cbe;
# }
# #T_9141a_row4_col1 {
#   background-color: #2182b9;
# }
# #T_9141a_row4_col2 {
#   background-color: #2c89bd;
# }
# #T_9141a_row5_col0 {
#   background-color: #328dbf;
# }
# #T_9141a_row5_col1 {
#   background-color: #1379b5;
# }
# #T_9141a_row5_col2 {
#   background-color: #65a3cb;
# }
# #T_9141a_row6_col0 {
#   background-color: #63a2cb;
# }
# #T_9141a_row6_col2 {
#   background-color: #97b7d7;
# }
# #T_9141a_row7_col1 {
#   background-color: #dfddec;
# }
# #T_9141a_row7_col2, #T_9141a_row12_col0, #T_9141a_row12_col1 {
#   background-color: #fff7fb;
# }
# #T_9141a_row8_col0 {
#   background-color: #569dc8;
# }
# #T_9141a_row8_col1 {
#   background-color: #358fc0;
# }
# #T_9141a_row8_col2 {
#   background-color: #2d8abd;
# }
# #T_9141a_row9_col0 {
#   background-color: #056aa6;
# }
# #T_9141a_row9_col1 {
#   background-color: #056dac;
# }
# #T_9141a_row9_col2 {
#   background-color: #157ab5;
# }
# #T_9141a_row10_col0, #T_9141a_row10_col1, #T_9141a_row11_col2 {
#   background-color: #045382;
# }
# #T_9141a_row10_col2 {
#   background-color: #045788;
# }
# #T_9141a_row11_col0 {
#   background-color: #05659f;
# }
# #T_9141a_row11_col1 {
#   background-color: #045b8f;
# }
# #T_9141a_row12_col2 {
#   background-color: #e2dfee;
# }
# </style>
# <table id="T_9141a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Track</th>
#       <th id="T_9141a_level0_col0" class="col_heading level0 col0" >Subtrack 1</th>
#       <th id="T_9141a_level0_col1" class="col_heading level0 col1" >Subtrack 2 [Strict]</th>
#       <th id="T_9141a_level0_col2" class="col_heading level0 col2" >Subtrack 2 [Merged]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Estrategia</th>
#       <th class="index_name level1" >Embeddings</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9141a_level0_row0" class="row_heading level0 row0" rowspan="7">FINETUNE</th>
#       <th id="T_9141a_level1_row0" class="row_heading level1 row0" >BETO</th>
#       <td id="T_9141a_row0_col0" class="data row0 col0" >96.88 ± 0.13</td>
#       <td id="T_9141a_row0_col1" class="data row0 col1" >97.64 ± 0.16</td>
#       <td id="T_9141a_row0_col2" class="data row0 col2" >98.37 ± 0.12</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row1" class="row_heading level1 row1" >BETO + CONTEXT</th>
#       <td id="T_9141a_row1_col0" class="data row1 col0" >97.09 ± 0.09</td>
#       <td id="T_9141a_row1_col1" class="data row1 col1" >97.78 ± 0.06</td>
#       <td id="T_9141a_row1_col2" class="data row1 col2" >98.44 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row2" class="row_heading level1 row2" >BETO + WE</th>
#       <td id="T_9141a_row2_col0" class="data row2 col0" >97.2 ± 0.05</td>
#       <td id="T_9141a_row2_col1" class="data row2 col1" >97.82 ± 0.07</td>
#       <td id="T_9141a_row2_col2" class="data row2 col2" >98.5 ± 0.05</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row3" class="row_heading level1 row3" >BETO + WE + CONTEXT</th>
#       <td id="T_9141a_row3_col0" class="data row3 col0" >97.5 ± 0.06</td>
#       <td id="T_9141a_row3_col1" class="data row3 col1" >98.09 ± 0.08</td>
#       <td id="T_9141a_row3_col2" class="data row3 col2" >98.67 ± 0.09</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row4" class="row_heading level1 row4" >XLMRL</th>
#       <td id="T_9141a_row4_col0" class="data row4 col0" >97.37 ± 0.07</td>
#       <td id="T_9141a_row4_col1" class="data row4 col1" >97.94 ± 0.04</td>
#       <td id="T_9141a_row4_col2" class="data row4 col2" >98.63 ± 0.06</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row5" class="row_heading level1 row5" >XLMRL + CONTEXT</th>
#       <td id="T_9141a_row5_col0" class="data row5 col0" >97.37 ± 0.16</td>
#       <td id="T_9141a_row5_col1" class="data row5 col1" >97.97 ± 0.15</td>
#       <td id="T_9141a_row5_col2" class="data row5 col2" >98.58 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row6" class="row_heading level1 row6" >XLMRL + WE</th>
#       <td id="T_9141a_row6_col0" class="data row6 col0" >97.28 ± 0.12</td>
#       <td id="T_9141a_row6_col1" class="data row6 col1" >97.9 ± 0.03</td>
#       <td id="T_9141a_row6_col2" class="data row6 col2" >98.54 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level0_row7" class="row_heading level0 row7" rowspan="6">LSTM CRF</th>
#       <th id="T_9141a_level1_row7" class="row_heading level1 row7" >BETO</th>
#       <td id="T_9141a_row7_col0" class="data row7 col0" >96.88 ± 0.09</td>
#       <td id="T_9141a_row7_col1" class="data row7 col1" >97.48 ± 0.06</td>
#       <td id="T_9141a_row7_col2" class="data row7 col2" >98.37 ± 0.02</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row8" class="row_heading level1 row8" >BETO + CONTEXT</th>
#       <td id="T_9141a_row8_col0" class="data row8 col0" >97.31 ± 0.09</td>
#       <td id="T_9141a_row8_col1" class="data row8 col1" >97.89 ± 0.02</td>
#       <td id="T_9141a_row8_col2" class="data row8 col2" >98.63 ± 0.07</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row9" class="row_heading level1 row9" >BETO + WE</th>
#       <td id="T_9141a_row9_col0" class="data row9 col0" >97.49 ± 0.07</td>
#       <td id="T_9141a_row9_col1" class="data row9 col1" >98.01 ± 0.07</td>
#       <td id="T_9141a_row9_col2" class="data row9 col2" >98.65 ± 0.05</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row10" class="row_heading level1 row10" >BETO + WE + CONTEXT</th>
#       <td id="T_9141a_row10_col0" class="data row10 col0" >97.59 ± 0.13</td>
#       <td id="T_9141a_row10_col1" class="data row10 col1" >98.14 ± 0.09</td>
#       <td id="T_9141a_row10_col2" class="data row10 col2" >98.72 ± 0.08</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row11" class="row_heading level1 row11" >FLAIR</th>
#       <td id="T_9141a_row11_col0" class="data row11 col0" >97.51 ± 0.14</td>
#       <td id="T_9141a_row11_col1" class="data row11 col1" >98.11 ± 0.14</td>
#       <td id="T_9141a_row11_col2" class="data row11 col2" >98.73 ± 0.09</td>
#     </tr>
#     <tr>
#       <th id="T_9141a_level1_row12" class="row_heading level1 row12" >FLAIR + WE</th>
#       <td id="T_9141a_row12_col0" class="data row12 col0" >96.84 ± 0.13</td>
#       <td id="T_9141a_row12_col1" class="data row12 col1" >97.31 ± 0.11</td>
#       <td id="T_9141a_row12_col2" class="data row12 col2" >98.44 ± 0.08</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Compare the previous results with the best score obtained with Flair.

# %%
diff = result_metrics[::2] - result_metrics.loc[("LSTM CRF", "FLAIR")].loc["mean"].values.squeeze()
diff = diff.drop([("LSTM CRF", "FLAIR"), ("LSTM CRF", "FLAIR + WE")])*100
glue("compare_with_flair", diff.style.pipe(make_pretty).hide(axis="index", level=[2, 3]).background_gradient())
# Out:
# <style type="text/css">
# #T_7ed24 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7ed24 th.level1 {
#   text-align: left;
# }
# #T_7ed24 th.level0 {
#   text-align: center;
# }
# #T_7ed24 th.col_heading {
#   text-align: center;
# }
# #T_7ed24 th.col_heading.level0 {
#   font-size: 1.5em;
# }
# #T_7ed24 td {
#   text-align: center;
#   font-weight: bold;
# }
# #T_7ed24_row0_col0, #T_7ed24_row7_col0, #T_7ed24_row7_col1, #T_7ed24_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7ed24_row0_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_7ed24_row0_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_7ed24_row1_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_7ed24_row1_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_7ed24_row1_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_7ed24_row2_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_7ed24_row2_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_7ed24_row2_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_7ed24_row3_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_7ed24_row3_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_7ed24_row3_col2 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_7ed24_row4_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_7ed24_row4_col1, #T_7ed24_row5_col0 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_7ed24_row4_col2 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_7ed24_row5_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_7ed24_row5_col2 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_7ed24_row6_col0 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_7ed24_row6_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_7ed24_row6_col2 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_7ed24_row8_col0 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_7ed24_row8_col1 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_7ed24_row8_col2 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_7ed24_row9_col0 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_7ed24_row9_col1 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_7ed24_row9_col2 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_7ed24_row10_col0, #T_7ed24_row10_col1, #T_7ed24_row10_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ed24">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Track</th>
#       <th id="T_7ed24_level0_col0" class="col_heading level0 col0" >Subtrack 1</th>
#       <th id="T_7ed24_level0_col1" class="col_heading level0 col1" >Subtrack 2 [Strict]</th>
#       <th id="T_7ed24_level0_col2" class="col_heading level0 col2" >Subtrack 2 [Merged]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Estrategia</th>
#       <th class="index_name level1" >Embeddings</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed24_level0_row0" class="row_heading level0 row0" rowspan="7">FINETUNE</th>
#       <th id="T_7ed24_level1_row0" class="row_heading level1 row0" >BETO</th>
#       <td id="T_7ed24_row0_col0" class="data row0 col0" >-0.64</td>
#       <td id="T_7ed24_row0_col1" class="data row0 col1" >-0.46</td>
#       <td id="T_7ed24_row0_col2" class="data row0 col2" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row1" class="row_heading level1 row1" >BETO + CONTEXT</th>
#       <td id="T_7ed24_row1_col0" class="data row1 col0" >-0.42</td>
#       <td id="T_7ed24_row1_col1" class="data row1 col1" >-0.33</td>
#       <td id="T_7ed24_row1_col2" class="data row1 col2" >-0.29</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row2" class="row_heading level1 row2" >BETO + WE</th>
#       <td id="T_7ed24_row2_col0" class="data row2 col0" >-0.31</td>
#       <td id="T_7ed24_row2_col1" class="data row2 col1" >-0.28</td>
#       <td id="T_7ed24_row2_col2" class="data row2 col2" >-0.23</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row3" class="row_heading level1 row3" >BETO + WE + CONTEXT</th>
#       <td id="T_7ed24_row3_col0" class="data row3 col0" >-0.02</td>
#       <td id="T_7ed24_row3_col1" class="data row3 col1" >-0.02</td>
#       <td id="T_7ed24_row3_col2" class="data row3 col2" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row4" class="row_heading level1 row4" >XLMRL</th>
#       <td id="T_7ed24_row4_col0" class="data row4 col0" >-0.14</td>
#       <td id="T_7ed24_row4_col1" class="data row4 col1" >-0.17</td>
#       <td id="T_7ed24_row4_col2" class="data row4 col2" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row5" class="row_heading level1 row5" >XLMRL + CONTEXT</th>
#       <td id="T_7ed24_row5_col0" class="data row5 col0" >-0.15</td>
#       <td id="T_7ed24_row5_col1" class="data row5 col1" >-0.14</td>
#       <td id="T_7ed24_row5_col2" class="data row5 col2" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row6" class="row_heading level1 row6" >XLMRL + WE</th>
#       <td id="T_7ed24_row6_col0" class="data row6 col0" >-0.23</td>
#       <td id="T_7ed24_row6_col1" class="data row6 col1" >-0.21</td>
#       <td id="T_7ed24_row6_col2" class="data row6 col2" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level0_row7" class="row_heading level0 row7" rowspan="4">LSTM CRF</th>
#       <th id="T_7ed24_level1_row7" class="row_heading level1 row7" >BETO</th>
#       <td id="T_7ed24_row7_col0" class="data row7 col0" >-0.64</td>
#       <td id="T_7ed24_row7_col1" class="data row7 col1" >-0.63</td>
#       <td id="T_7ed24_row7_col2" class="data row7 col2" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row8" class="row_heading level1 row8" >BETO + CONTEXT</th>
#       <td id="T_7ed24_row8_col0" class="data row8 col0" >-0.21</td>
#       <td id="T_7ed24_row8_col1" class="data row8 col1" >-0.22</td>
#       <td id="T_7ed24_row8_col2" class="data row8 col2" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row9" class="row_heading level1 row9" >BETO + WE</th>
#       <td id="T_7ed24_row9_col0" class="data row9 col0" >-0.02</td>
#       <td id="T_7ed24_row9_col1" class="data row9 col1" >-0.09</td>
#       <td id="T_7ed24_row9_col2" class="data row9 col2" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_7ed24_level1_row10" class="row_heading level1 row10" >BETO + WE + CONTEXT</th>
#       <td id="T_7ed24_row10_col0" class="data row10 col0" >0.07</td>
#       <td id="T_7ed24_row10_col1" class="data row10 col1" >0.03</td>
#       <td id="T_7ed24_row10_col2" class="data row10 col2" >-0.01</td>
#     </tr>
#   </tbody>
# </table>
